# %%
import torch
import numpy as np
import multiprocessing as mp
import graph_alg as ga

import time

# %%
def sinkhorn_knopp(matrix, max_iter=1000, tol=1e-6):
    for _ in range(max_iter):
        matrix /= matrix.sum(axis=1, keepdims=True)  # 行ごとに正規化
        matrix /= matrix.sum(axis=0, keepdims=True)  # 列ごとに正規化
        
        if np.allclose(matrix.sum(axis=1), 1, atol=tol) and np.allclose(matrix.sum(axis=0), 1, atol=tol):
            break
    
    return matrix


def generate_permutation_array(N, num_goods):
    P = np.zeros((N, num_goods))
    for i in range(N): 
        P[i] = np.random.permutation(num_goods)
    
    return P


def sample_ranking(N, num_goods):
        """ 
        Samples ranked lists
        Arguments
            N: Number of samples
            prob: Probability of truncation       
        Returns:
            Ranked List of shape [N, Num_agents]
        """
        P = generate_permutation_array(N, num_goods) + 1
        
        return P / num_goods

    
def generate_batch(batch_size, num_goods):
        """
        Samples a batch of data from training
        Arguments
            batch_size: number of samples
            prob: probability of truncation
        Returns
            P: Agent's preferences, 
                P_{ij}: How much Agent-i prefers to be Good-j
        """
        N = batch_size * num_goods
        P = sample_ranking(N, num_goods).reshape(-1, num_goods, num_goods)
        return P

# %%
num_iterations = 100  # 繰り返し回数
batch_size = 1
num_goods = 4

for i in range(num_iterations):
    start_time = time.perf_counter()  # 開始時刻の計測
    
    # ランダムな割り当て行列の生成と処理
    randomassignment = np.random.rand(batch_size, num_goods, num_goods)
    RandomAssignment = np.array([sinkhorn_knopp(matrix) for matrix in randomassignment])
    
    # 好み（preferences）の生成
    preferences = generate_batch(batch_size, num_goods)
    
    # numpy配列から PyTorch の tensor に変換
    P = torch.tensor(RandomAssignment, dtype=torch.float32)
    Preferences = torch.tensor(preferences, dtype=torch.float32)
    
    # 入力データの表示
    print(f"Iteration {i+1}")
    print("P: ", P)
    print("Preferences: ", Preferences)
    
    # グラフアルゴリズムによる処理
    ev = ga.compute_ev(P, Preferences)
    violations, cycles = ev.execute_all_cycles_batch()
    print("Violations:", violations)
    end_time = time.perf_counter()  # 終了時刻の計測
    print(f"Time taken for iteration {i+1}: {end_time - start_time:.6f} sec")
    print("Cycles:", cycles)
    #print("CPU Count:", cpucount)
    
    
    print("-" * 50)
# Out:
# Iteration 1
# P:  tensor([[[0.1376, 0.1992, 0.4998, 0.1634],
#          [0.2422, 0.2375, 0.1050, 0.4152],
#          [0.1791, 0.3948, 0.1625, 0.2636],
#          [0.4411, 0.1685, 0.2327, 0.1577]]])
# Preferences:  tensor([[[0.7500, 0.2500, 0.5000, 1.0000],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.5000, 0.2500, 0.7500, 1.0000]]])
# Violations: tensor([[1.4628]])
# Time taken for iteration 1: 0.773345 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 2
# P:  tensor([[[0.2334, 0.3503, 0.3151, 0.1012],
#          [0.0894, 0.3235, 0.1421, 0.4450],
#          [0.2967, 0.3066, 0.3896, 0.0071],
#          [0.3806, 0.0196, 0.1532, 0.4466]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[1.9055]])
# Time taken for iteration 2: 0.756175 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 3
# P:  tensor([[[0.2989, 0.2302, 0.0576, 0.4133],
#          [0.3835, 0.2276, 0.2468, 0.1421],
#          [0.0559, 0.2824, 0.4114, 0.2502],
#          [0.2617, 0.2597, 0.2841, 0.1945]]])
# Preferences:  tensor([[[0.7500, 1.0000, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.2580]])
# Time taken for iteration 3: 0.713919 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 4
# P:  tensor([[[0.0945, 0.2648, 0.4209, 0.2199],
#          [0.2962, 0.1666, 0.1305, 0.4068],
#          [0.2277, 0.2876, 0.2777, 0.2071],
#          [0.3817, 0.2811, 0.1710, 0.1663]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.2500, 0.5000, 0.7500, 1.0000]]])
# Violations: tensor([[1.6732]])
# Time taken for iteration 4: 0.729246 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 5
# P:  tensor([[[0.3196, 0.1729, 0.2281, 0.2794],
#          [0.4071, 0.1344, 0.3068, 0.1517],
#          [0.0226, 0.5235, 0.3073, 0.1466],
#          [0.2507, 0.1692, 0.1579, 0.4222]]])
# Preferences:  tensor([[[0.2500, 0.5000, 1.0000, 0.7500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500]]])
# Violations: tensor([[1.5788]])
# Time taken for iteration 5: 0.781426 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 6
# P:  tensor([[[0.1859, 0.0455, 0.4120, 0.3566],
#          [0.1713, 0.3532, 0.2399, 0.2356],
#          [0.1881, 0.4099, 0.2433, 0.1588],
#          [0.4547, 0.1914, 0.1049, 0.2490]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[0.8503]])
# Time taken for iteration 6: 0.733257 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 7
# P:  tensor([[[0.2266, 0.0726, 0.4127, 0.2881],
#          [0.2036, 0.6221, 0.0081, 0.1662],
#          [0.3726, 0.0415, 0.5643, 0.0216],
#          [0.1972, 0.2638, 0.0149, 0.5241]]])
# Preferences:  tensor([[[1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.2500, 0.7500, 0.5000, 1.0000]]])
# Violations: tensor([[0.5751]])
# Time taken for iteration 7: 0.708774 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 8
# P:  tensor([[[0.3813, 0.1697, 0.1593, 0.2896],
#          [0.3048, 0.0498, 0.2935, 0.3518],
#          [0.2001, 0.4662, 0.2675, 0.0661],
#          [0.1138, 0.3142, 0.2796, 0.2924]]])
# Preferences:  tensor([[[0.2500, 0.5000, 0.7500, 1.0000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.7500, 0.5000, 0.2500, 1.0000]]])
# Violations: tensor([[1.0778]])
# Time taken for iteration 8: 0.729058 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 9
# P:  tensor([[[0.1765, 0.2710, 0.3330, 0.2195],
#          [0.3913, 0.3048, 0.0442, 0.2597],
#          [0.2304, 0.2938, 0.2375, 0.2383],
#          [0.2018, 0.1304, 0.3852, 0.2825]]])
# Preferences:  tensor([[[0.7500, 0.5000, 0.2500, 1.0000],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.7500, 0.2500, 0.5000, 1.0000]]])
# Violations: tensor([[1.2989]])
# Time taken for iteration 9: 0.705708 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 10
# P:  tensor([[[0.1525, 0.3196, 0.3197, 0.2081],
#          [0.3241, 0.2875, 0.1648, 0.2236],
#          [0.2909, 0.2595, 0.0212, 0.4284],
#          [0.2324, 0.1334, 0.4943, 0.1399]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[0.8714]])
# Time taken for iteration 10: 0.731507 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 11
# P:  tensor([[[0.1230, 0.4161, 0.3519, 0.1091],
#          [0.1831, 0.4212, 0.2673, 0.1284],
#          [0.2204, 0.1324, 0.2573, 0.3900],
#          [0.4736, 0.0303, 0.1235, 0.3726]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[0.7409]])
# Time taken for iteration 11: 0.727352 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 12
# P:  tensor([[[0.1414, 0.2472, 0.4247, 0.1866],
#          [0.1510, 0.1831, 0.3055, 0.3604],
#          [0.3298, 0.2916, 0.2504, 0.1283],
#          [0.3778, 0.2782, 0.0193, 0.3247]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [0.5000, 0.2500, 1.0000, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000]]])
# Violations: tensor([[1.1405]])
# Time taken for iteration 12: 0.715500 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 13
# P:  tensor([[[0.4996, 0.0056, 0.3677, 0.1271],
#          [0.1893, 0.2146, 0.2736, 0.3226],
#          [0.2279, 0.4121, 0.0828, 0.2772],
#          [0.0832, 0.3677, 0.2759, 0.2731]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [1.0000, 0.5000, 0.2500, 0.7500]]])
# Violations: tensor([[0.6389]])
# Time taken for iteration 13: 0.714390 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 14
# P:  tensor([[[0.0338, 0.3419, 0.4368, 0.1875],
#          [0.3267, 0.0420, 0.3416, 0.2898],
#          [0.3543, 0.2390, 0.1242, 0.2825],
#          [0.2852, 0.3771, 0.0975, 0.2402]]])
# Preferences:  tensor([[[1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[1.2529]])
# Time taken for iteration 14: 0.721521 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 15
# P:  tensor([[[0.0233, 0.2575, 0.5067, 0.2124],
#          [0.1610, 0.1515, 0.1707, 0.5168],
#          [0.5612, 0.3561, 0.0295, 0.0532],
#          [0.2545, 0.2349, 0.2931, 0.2175]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.2500, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[1.6416]])
# Time taken for iteration 15: 0.731370 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 16
# P:  tensor([[[0.0403, 0.3914, 0.4545, 0.1138],
#          [0.5762, 0.1571, 0.0990, 0.1678],
#          [0.0894, 0.2803, 0.4213, 0.2091],
#          [0.2942, 0.1712, 0.0252, 0.5094]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[1.5143]])
# Time taken for iteration 16: 0.666035 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 17
# P:  tensor([[[0.1829, 0.5869, 0.0360, 0.1942],
#          [0.2561, 0.2588, 0.1361, 0.3491],
#          [0.0582, 0.0228, 0.6130, 0.3060],
#          [0.5029, 0.1315, 0.2150, 0.1507]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.2500, 0.5000],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[0.5971]])
# Time taken for iteration 17: 0.690863 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 18
# P:  tensor([[[0.1694, 0.2233, 0.3699, 0.2374],
#          [0.2127, 0.2590, 0.1902, 0.3382],
#          [0.3282, 0.1173, 0.3605, 0.1940],
#          [0.2897, 0.4004, 0.0794, 0.2304]]])
# Preferences:  tensor([[[0.2500, 0.7500, 1.0000, 0.5000],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[0.8139]])
# Time taken for iteration 18: 0.676428 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 19
# P:  tensor([[[0.2278, 0.2170, 0.4172, 0.1380],
#          [0.3665, 0.3386, 0.1292, 0.1657],
#          [0.2327, 0.1922, 0.2346, 0.3404],
#          [0.1730, 0.2522, 0.2190, 0.3558]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [0.5000, 1.0000, 0.7500, 0.2500]]])
# Violations: tensor([[0.7210]])
# Time taken for iteration 19: 0.674437 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 20
# P:  tensor([[[0.3165, 0.3586, 0.1493, 0.1757],
#          [0.3035, 0.3681, 0.2491, 0.0794],
#          [0.1630, 0.1719, 0.3488, 0.3162],
#          [0.2170, 0.1014, 0.2528, 0.4288]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.2500, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.5000, 0.7500]]])
# Violations: tensor([[0.6158]])
# Time taken for iteration 20: 0.721084 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 21
# P:  tensor([[[0.4687, 0.2162, 0.1429, 0.1723],
#          [0.0618, 0.2848, 0.1911, 0.4623],
#          [0.1443, 0.2393, 0.2987, 0.3177],
#          [0.3252, 0.2597, 0.3674, 0.0478]]])
# Preferences:  tensor([[[0.7500, 1.0000, 0.2500, 0.5000],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.5000, 0.7500, 0.2500, 1.0000]]])
# Violations: tensor([[1.3726]])
# Time taken for iteration 21: 0.671699 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 22
# P:  tensor([[[0.4102, 0.2274, 0.0782, 0.2842],
#          [0.2672, 0.3114, 0.1283, 0.2931],
#          [0.3166, 0.1922, 0.3308, 0.1604],
#          [0.0060, 0.2690, 0.4627, 0.2623]]])
# Preferences:  tensor([[[0.2500, 0.5000, 1.0000, 0.7500],
#          [0.7500, 0.5000, 0.2500, 1.0000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 1.0000, 0.5000, 0.7500]]])
# Violations: tensor([[1.2627]])
# Time taken for iteration 22: 0.697299 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 23
# P:  tensor([[[0.0286, 0.6910, 0.2452, 0.0353],
#          [0.5878, 0.1351, 0.0551, 0.2220],
#          [0.3741, 0.1019, 0.2548, 0.2693],
#          [0.0095, 0.0721, 0.4449, 0.4735]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.2137]])
# Time taken for iteration 23: 0.705134 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 24
# P:  tensor([[[0.1802, 0.3994, 0.3233, 0.0971],
#          [0.2232, 0.1812, 0.3358, 0.2598],
#          [0.3174, 0.3343, 0.0987, 0.2496],
#          [0.2792, 0.0852, 0.2422, 0.3935]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.7500, 0.5000, 0.2500, 1.0000]]])
# Violations: tensor([[1.2097]])
# Time taken for iteration 24: 0.725018 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 25
# P:  tensor([[[0.1452, 0.1759, 0.2913, 0.3877],
#          [0.2705, 0.0757, 0.3949, 0.2589],
#          [0.3071, 0.2846, 0.1811, 0.2273],
#          [0.2772, 0.4638, 0.1328, 0.1262]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [0.5000, 0.2500, 0.7500, 1.0000],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[0.7204]])
# Time taken for iteration 25: 0.708919 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 26
# P:  tensor([[[0.0929, 0.3944, 0.2173, 0.2955],
#          [0.5563, 0.1422, 0.1046, 0.1969],
#          [0.3132, 0.3641, 0.0821, 0.2407],
#          [0.0376, 0.0994, 0.5960, 0.2670]]])
# Preferences:  tensor([[[0.5000, 0.7500, 1.0000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[0.9685]])
# Time taken for iteration 26: 0.710419 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 27
# P:  tensor([[[0.4204, 0.2506, 0.2518, 0.0772],
#          [0.3221, 0.2295, 0.2359, 0.2126],
#          [0.0720, 0.4212, 0.3367, 0.1701],
#          [0.1855, 0.0987, 0.1756, 0.5401]]])
# Preferences:  tensor([[[0.2500, 0.7500, 1.0000, 0.5000],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.5000, 0.7500, 1.0000, 0.2500]]])
# Violations: tensor([[1.1972]])
# Time taken for iteration 27: 0.683676 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 28
# P:  tensor([[[0.2235, 0.1088, 0.2777, 0.3900],
#          [0.1379, 0.2758, 0.3659, 0.2203],
#          [0.2759, 0.2494, 0.1796, 0.2950],
#          [0.3626, 0.3659, 0.1768, 0.0947]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000]]])
# Violations: tensor([[0.6609]])
# Time taken for iteration 28: 0.685422 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 29
# P:  tensor([[[0.0982, 0.0931, 0.3962, 0.4125],
#          [0.2444, 0.3848, 0.1192, 0.2517],
#          [0.3576, 0.4653, 0.0188, 0.1584],
#          [0.2999, 0.0568, 0.4658, 0.1775]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[1.3614]])
# Time taken for iteration 29: 0.729111 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 30
# P:  tensor([[[0.4879, 0.1954, 0.2667, 0.0500],
#          [0.0016, 0.4529, 0.4139, 0.1316],
#          [0.1476, 0.2138, 0.1963, 0.4423],
#          [0.3629, 0.1380, 0.1230, 0.3761]]])
# Preferences:  tensor([[[0.2500, 0.5000, 1.0000, 0.7500],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.5000, 1.0000, 0.2500, 0.7500]]])
# Violations: tensor([[0.9582]])
# Time taken for iteration 30: 0.714716 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 31
# P:  tensor([[[0.1461, 0.2145, 0.3081, 0.3313],
#          [0.0613, 0.2488, 0.3679, 0.3220],
#          [0.4606, 0.1979, 0.1391, 0.2024],
#          [0.3320, 0.3388, 0.1849, 0.1443]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.5000, 1.0000, 0.7500, 0.2500]]])
# Violations: tensor([[0.8566]])
# Time taken for iteration 31: 0.707183 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 32
# P:  tensor([[[0.4083, 0.0910, 0.2988, 0.2019],
#          [0.0788, 0.3165, 0.1296, 0.4750],
#          [0.4448, 0.3090, 0.0115, 0.2346],
#          [0.0681, 0.2835, 0.5600, 0.0884]]])
# Preferences:  tensor([[[0.7500, 1.0000, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 0.5000, 0.7500, 1.0000]]])
# Violations: tensor([[0.7964]])
# Time taken for iteration 32: 0.688709 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 33
# P:  tensor([[[0.0923, 0.5160, 0.0741, 0.3175],
#          [0.0691, 0.2034, 0.3349, 0.3926],
#          [0.1874, 0.2370, 0.2878, 0.2879],
#          [0.6512, 0.0436, 0.3032, 0.0020]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [1.0000, 0.5000, 0.2500, 0.7500]]])
# Violations: tensor([[1.0369]])
# Time taken for iteration 33: 0.683398 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 34
# P:  tensor([[[0.2679, 0.0284, 0.3382, 0.3654],
#          [0.3794, 0.1459, 0.4523, 0.0224],
#          [0.1460, 0.6087, 0.1663, 0.0790],
#          [0.2067, 0.2170, 0.0432, 0.5332]]])
# Preferences:  tensor([[[0.2500, 0.5000, 1.0000, 0.7500],
#          [0.5000, 0.2500, 0.7500, 1.0000],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.2500, 0.7500, 0.5000, 1.0000]]])
# Violations: tensor([[0.5545]])
# Time taken for iteration 34: 0.688408 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 35
# P:  tensor([[[0.3991, 0.1004, 0.2713, 0.2292],
#          [0.0972, 0.6193, 0.1125, 0.1710],
#          [0.3700, 0.0969, 0.2961, 0.2370],
#          [0.1337, 0.1835, 0.3201, 0.3627]]])
# Preferences:  tensor([[[0.7500, 0.2500, 0.5000, 1.0000],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.7500, 1.0000, 0.5000, 0.2500]]])
# Violations: tensor([[1.1011]])
# Time taken for iteration 35: 0.681932 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 36
# P:  tensor([[[0.1360, 0.2819, 0.2770, 0.3052],
#          [0.3106, 0.0991, 0.3947, 0.1956],
#          [0.0270, 0.3933, 0.3018, 0.2779],
#          [0.5264, 0.2258, 0.0265, 0.2213]]])
# Preferences:  tensor([[[0.2500, 1.0000, 0.7500, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [0.5000, 0.2500, 1.0000, 0.7500],
#          [0.5000, 0.7500, 0.2500, 1.0000]]])
# Violations: tensor([[1.0028]])
# Time taken for iteration 36: 0.731799 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 37
# P:  tensor([[[0.1789, 0.2450, 0.4605, 0.1156],
#          [0.3538, 0.1600, 0.0269, 0.4592],
#          [0.3674, 0.1917, 0.2759, 0.1651],
#          [0.0999, 0.4033, 0.2367, 0.2600]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[1.2074]])
# Time taken for iteration 37: 0.725282 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 38
# P:  tensor([[[0.1522, 0.6396, 0.1164, 0.0918],
#          [0.1642, 0.0723, 0.3597, 0.4038],
#          [0.5108, 0.1688, 0.2687, 0.0516],
#          [0.1728, 0.1193, 0.2551, 0.4528]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[0.9478]])
# Time taken for iteration 38: 0.667166 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 39
# P:  tensor([[[0.2839, 0.2458, 0.2366, 0.2336],
#          [0.2005, 0.1744, 0.3572, 0.2679],
#          [0.3422, 0.3370, 0.0941, 0.2266],
#          [0.1733, 0.2428, 0.3121, 0.2718]]])
# Preferences:  tensor([[[0.7500, 1.0000, 0.2500, 0.5000],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500]]])
# Violations: tensor([[1.4713]])
# Time taken for iteration 39: 0.660577 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 40
# P:  tensor([[[0.0301, 0.4931, 0.0132, 0.4636],
#          [0.5560, 0.0199, 0.3836, 0.0405],
#          [0.1302, 0.1519, 0.3496, 0.3682],
#          [0.2837, 0.3351, 0.2536, 0.1276]]])
# Preferences:  tensor([[[1.0000, 0.2500, 0.7500, 0.5000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[0.9396]])
# Time taken for iteration 40: 0.688048 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 41
# P:  tensor([[[0.2825, 0.0053, 0.2806, 0.4316],
#          [0.1987, 0.3120, 0.2718, 0.2175],
#          [0.0242, 0.3867, 0.2771, 0.3120],
#          [0.4946, 0.2960, 0.1705, 0.0389]]])
# Preferences:  tensor([[[0.5000, 0.2500, 0.7500, 1.0000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[0.8616]])
# Time taken for iteration 41: 0.703185 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 42
# P:  tensor([[[0.0274, 0.2445, 0.3838, 0.3444],
#          [0.3972, 0.2348, 0.2272, 0.1408],
#          [0.3720, 0.2838, 0.0765, 0.2678],
#          [0.2034, 0.2370, 0.3125, 0.2471]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500]]])
# Violations: tensor([[1.3076]])
# Time taken for iteration 42: 0.712476 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 43
# P:  tensor([[[0.2672, 0.1651, 0.3444, 0.2233],
#          [0.1731, 0.1355, 0.3673, 0.3241],
#          [0.3240, 0.3838, 0.0547, 0.2374],
#          [0.2357, 0.3155, 0.2336, 0.2152]]])
# Preferences:  tensor([[[0.7500, 0.5000, 0.2500, 1.0000],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [1.0000, 0.7500, 0.2500, 0.5000]]])
# Violations: tensor([[1.9652]])
# Time taken for iteration 43: 0.682632 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 44
# P:  tensor([[[0.2304, 0.3779, 0.2185, 0.1732],
#          [0.1060, 0.2077, 0.2118, 0.4745],
#          [0.4008, 0.2189, 0.2511, 0.1292],
#          [0.2628, 0.1955, 0.3185, 0.2231]]])
# Preferences:  tensor([[[0.7500, 0.2500, 1.0000, 0.5000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500]]])
# Violations: tensor([[1.1938]])
# Time taken for iteration 44: 0.665776 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 45
# P:  tensor([[[0.3522, 0.2986, 0.1793, 0.1700],
#          [0.2039, 0.1910, 0.3138, 0.2913],
#          [0.2633, 0.3052, 0.0702, 0.3613],
#          [0.1806, 0.2053, 0.4368, 0.1774]]])
# Preferences:  tensor([[[0.7500, 0.5000, 0.2500, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[0.9406]])
# Time taken for iteration 45: 0.684271 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 46
# P:  tensor([[[0.0537, 0.0563, 0.5657, 0.3242],
#          [0.6193, 0.0379, 0.1381, 0.2046],
#          [0.2695, 0.5628, 0.0848, 0.0829],
#          [0.0574, 0.3430, 0.2114, 0.3882]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[1.8384]])
# Time taken for iteration 46: 0.701472 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 47
# P:  tensor([[[0.4337, 0.2212, 0.1185, 0.2266],
#          [0.3677, 0.3561, 0.1653, 0.1108],
#          [0.0243, 0.2264, 0.3569, 0.3924],
#          [0.1743, 0.1963, 0.3593, 0.2702]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.7500, 0.5000, 0.2500, 1.0000],
#          [0.2500, 1.0000, 0.7500, 0.5000]]])
# Violations: tensor([[1.6605]])
# Time taken for iteration 47: 0.689869 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 48
# P:  tensor([[[0.1752, 0.0847, 0.4496, 0.2905],
#          [0.3812, 0.1236, 0.0363, 0.4589],
#          [0.0444, 0.4228, 0.2985, 0.2343],
#          [0.3992, 0.3689, 0.2156, 0.0163]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [0.5000, 0.2500, 0.7500, 1.0000]]])
# Violations: tensor([[1.9070]])
# Time taken for iteration 48: 0.665922 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 49
# P:  tensor([[[0.2614, 0.2780, 0.1036, 0.3571],
#          [0.0809, 0.1378, 0.2609, 0.5204],
#          [0.4002, 0.0330, 0.4826, 0.0842],
#          [0.2575, 0.5512, 0.1530, 0.0383]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.2500, 0.5000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.2500, 1.0000, 0.7500, 0.5000]]])
# Violations: tensor([[0.7803]])
# Time taken for iteration 49: 0.689702 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 50
# P:  tensor([[[0.1080, 0.1665, 0.2106, 0.5150],
#          [0.1193, 0.1916, 0.3800, 0.3091],
#          [0.2327, 0.4139, 0.2390, 0.1144],
#          [0.5401, 0.2280, 0.1704, 0.0615]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [0.7500, 1.0000, 0.5000, 0.2500]]])
# Violations: tensor([[1.2437]])
# Time taken for iteration 50: 0.765495 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 51
# P:  tensor([[[0.2529, 0.2705, 0.1719, 0.3047],
#          [0.3738, 0.1645, 0.3506, 0.1111],
#          [0.1338, 0.4138, 0.2227, 0.2297],
#          [0.2395, 0.1511, 0.2549, 0.3545]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.2500, 0.7500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.7500, 1.0000, 0.2500, 0.5000]]])
# Violations: tensor([[1.0227]])
# Time taken for iteration 51: 0.740043 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 52
# P:  tensor([[[0.2156, 0.2106, 0.1781, 0.3958],
#          [0.3685, 0.3354, 0.2902, 0.0058],
#          [0.2236, 0.2396, 0.2967, 0.2400],
#          [0.1923, 0.2143, 0.2349, 0.3584]]])
# Preferences:  tensor([[[0.5000, 0.7500, 1.0000, 0.2500],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[1.6831]])
# Time taken for iteration 52: 0.729321 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 53
# P:  tensor([[[0.3071, 0.3118, 0.0361, 0.3450],
#          [0.4686, 0.3127, 0.0250, 0.1937],
#          [0.0621, 0.1923, 0.4771, 0.2686],
#          [0.1622, 0.1832, 0.4619, 0.1927]]])
# Preferences:  tensor([[[0.2500, 0.5000, 0.7500, 1.0000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[0.9617]])
# Time taken for iteration 53: 0.703887 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 54
# P:  tensor([[[0.1044, 0.3364, 0.2513, 0.3079],
#          [0.2214, 0.2115, 0.4122, 0.1549],
#          [0.2966, 0.3002, 0.0770, 0.3263],
#          [0.3777, 0.1519, 0.2595, 0.2109]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 0.5000, 0.2500, 1.0000]]])
# Violations: tensor([[0.7823]])
# Time taken for iteration 54: 0.688662 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 55
# P:  tensor([[[0.5457, 0.0113, 0.1104, 0.3326],
#          [0.2594, 0.3840, 0.2058, 0.1508],
#          [0.0944, 0.1689, 0.3255, 0.4111],
#          [0.1005, 0.4358, 0.3582, 0.1054]]])
# Preferences:  tensor([[[0.7500, 0.5000, 0.2500, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [1.0000, 0.5000, 0.2500, 0.7500]]])
# Violations: tensor([[1.4597]])
# Time taken for iteration 55: 0.707504 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 56
# P:  tensor([[[0.0255, 0.0925, 0.4214, 0.4605],
#          [0.3386, 0.2567, 0.1605, 0.2443],
#          [0.3316, 0.2883, 0.2000, 0.1801],
#          [0.3043, 0.3625, 0.2181, 0.1151]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[1.1331]])
# Time taken for iteration 56: 0.724911 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 57
# P:  tensor([[[0.2168, 0.3626, 0.2106, 0.2100],
#          [0.0999, 0.5262, 0.2455, 0.1284],
#          [0.3414, 0.0592, 0.3127, 0.2866],
#          [0.3419, 0.0520, 0.2311, 0.3750]]])
# Preferences:  tensor([[[0.2500, 0.7500, 1.0000, 0.5000],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000]]])
# Violations: tensor([[1.1984]])
# Time taken for iteration 57: 0.697249 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 58
# P:  tensor([[[0.1708, 0.3108, 0.2221, 0.2963],
#          [0.2500, 0.2359, 0.4096, 0.1046],
#          [0.4524, 0.0205, 0.0677, 0.4594],
#          [0.1268, 0.4328, 0.3006, 0.1397]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.7500, 0.2500, 1.0000, 0.5000]]])
# Violations: tensor([[1.6894]])
# Time taken for iteration 58: 0.750693 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 59
# P:  tensor([[[0.1789, 0.4325, 0.2042, 0.1844],
#          [0.0653, 0.5023, 0.3255, 0.1070],
#          [0.3086, 0.0178, 0.1914, 0.4822],
#          [0.4472, 0.0474, 0.2790, 0.2264]]])
# Preferences:  tensor([[[0.7500, 0.5000, 1.0000, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [1.0000, 0.7500, 0.5000, 0.2500]]])
# Violations: tensor([[1.1898]])
# Time taken for iteration 59: 0.686435 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 60
# P:  tensor([[[0.1154, 0.4016, 0.2867, 0.1963],
#          [0.4096, 0.1333, 0.2384, 0.2187],
#          [0.1548, 0.2844, 0.4628, 0.0980],
#          [0.3202, 0.1807, 0.0121, 0.4870]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000]]])
# Violations: tensor([[0.5810]])
# Time taken for iteration 60: 0.699679 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 61
# P:  tensor([[[0.3605, 0.1325, 0.2907, 0.2163],
#          [0.2717, 0.2056, 0.2997, 0.2230],
#          [0.2948, 0.4001, 0.1910, 0.1141],
#          [0.0731, 0.2618, 0.2186, 0.4465]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [1.0000, 0.5000, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000]]])
# Violations: tensor([[0.9924]])
# Time taken for iteration 61: 0.665051 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 62
# P:  tensor([[[0.0521, 0.1063, 0.2864, 0.5552],
#          [0.3040, 0.3849, 0.2624, 0.0487],
#          [0.2843, 0.2002, 0.1747, 0.3408],
#          [0.3597, 0.3085, 0.2765, 0.0554]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [1.0000, 0.7500, 0.2500, 0.5000]]])
# Violations: tensor([[0.8231]])
# Time taken for iteration 62: 0.708071 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 63
# P:  tensor([[[0.2036, 0.6444, 0.0706, 0.0815],
#          [0.1388, 0.0660, 0.4126, 0.3826],
#          [0.0970, 0.2193, 0.5079, 0.1759],
#          [0.5607, 0.0703, 0.0089, 0.3601]]])
# Preferences:  tensor([[[0.5000, 0.2500, 0.7500, 1.0000],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.2500, 0.7500, 1.0000, 0.5000]]])
# Violations: tensor([[1.8463]])
# Time taken for iteration 63: 0.680285 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 64
# P:  tensor([[[0.2325, 0.2446, 0.2426, 0.2802],
#          [0.2822, 0.0701, 0.4069, 0.2408],
#          [0.1426, 0.3199, 0.2822, 0.2553],
#          [0.3427, 0.3655, 0.0682, 0.2237]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[0.9575]])
# Time taken for iteration 64: 0.679235 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 65
# P:  tensor([[[0.3039, 0.1594, 0.3469, 0.1898],
#          [0.3892, 0.2098, 0.0023, 0.3987],
#          [0.2635, 0.3215, 0.3350, 0.0801],
#          [0.0435, 0.3093, 0.3158, 0.3314]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [1.0000, 0.5000, 0.7500, 0.2500]]])
# Violations: tensor([[1.4532]])
# Time taken for iteration 65: 0.689532 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 66
# P:  tensor([[[0.0970, 0.4236, 0.1460, 0.3334],
#          [0.7159, 0.1103, 0.0581, 0.1157],
#          [0.0220, 0.0514, 0.5864, 0.3402],
#          [0.1650, 0.4147, 0.2096, 0.2106]]])
# Preferences:  tensor([[[0.7500, 0.2500, 0.5000, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [1.0000, 0.5000, 0.7500, 0.2500],
#          [1.0000, 0.7500, 0.2500, 0.5000]]])
# Violations: tensor([[1.5921]])
# Time taken for iteration 66: 0.715877 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 67
# P:  tensor([[[0.3375, 0.0016, 0.1615, 0.4993],
#          [0.1504, 0.4831, 0.2792, 0.0874],
#          [0.3210, 0.3049, 0.1460, 0.2280],
#          [0.1911, 0.2103, 0.4133, 0.1853]]])
# Preferences:  tensor([[[1.0000, 0.2500, 0.7500, 0.5000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.2500, 0.7500, 0.5000, 1.0000]]])
# Violations: tensor([[1.1115]])
# Time taken for iteration 67: 0.801422 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 68
# P:  tensor([[[0.1097, 0.2352, 0.3313, 0.3238],
#          [0.1616, 0.4195, 0.1866, 0.2324],
#          [0.5119, 0.1123, 0.2201, 0.1558],
#          [0.2168, 0.2331, 0.2620, 0.2880]]])
# Preferences:  tensor([[[0.5000, 0.2500, 0.7500, 1.0000],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[0.8686]])
# Time taken for iteration 68: 0.698947 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 69
# P:  tensor([[[0.3423, 0.3125, 0.1805, 0.1647],
#          [0.1706, 0.2727, 0.2320, 0.3247],
#          [0.0950, 0.2941, 0.3146, 0.2964],
#          [0.3921, 0.1208, 0.2729, 0.2142]]])
# Preferences:  tensor([[[0.5000, 0.7500, 0.2500, 1.0000],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.2500, 0.5000, 0.7500, 1.0000]]])
# Violations: tensor([[1.1138]])
# Time taken for iteration 69: 0.790820 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 70
# P:  tensor([[[0.2050, 0.1965, 0.2138, 0.3847],
#          [0.4616, 0.3999, 0.0635, 0.0750],
#          [0.3021, 0.1647, 0.4900, 0.0432],
#          [0.0314, 0.2389, 0.2327, 0.4970]]])
# Preferences:  tensor([[[0.7500, 0.5000, 0.2500, 1.0000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.2500, 0.5000, 0.7500, 1.0000]]])
# Violations: tensor([[0.7497]])
# Time taken for iteration 70: 0.779838 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 71
# P:  tensor([[[0.2665, 0.2389, 0.2392, 0.2554],
#          [0.2938, 0.2859, 0.1288, 0.2915],
#          [0.3152, 0.2199, 0.3373, 0.1276],
#          [0.1245, 0.2552, 0.2947, 0.3255]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 0.7500, 1.0000, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[0.7870]])
# Time taken for iteration 71: 0.792428 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 72
# P:  tensor([[[0.2006, 0.1540, 0.2468, 0.3986],
#          [0.2260, 0.3490, 0.2224, 0.2026],
#          [0.2585, 0.3813, 0.2606, 0.0996],
#          [0.3150, 0.1156, 0.2702, 0.2992]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [1.0000, 0.5000, 0.2500, 0.7500],
#          [0.5000, 1.0000, 0.2500, 0.7500]]])
# Violations: tensor([[1.1043]])
# Time taken for iteration 72: 0.797171 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 73
# P:  tensor([[[0.3131, 0.1035, 0.1912, 0.3921],
#          [0.1112, 0.1650, 0.5135, 0.2103],
#          [0.2229, 0.3542, 0.2252, 0.1977],
#          [0.3527, 0.3773, 0.0701, 0.2000]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.5000, 0.2500, 0.7500, 1.0000]]])
# Violations: tensor([[1.6908]])
# Time taken for iteration 73: 0.694870 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 74
# P:  tensor([[[0.2383, 0.3431, 0.3122, 0.1064],
#          [0.4516, 0.0569, 0.3087, 0.1828],
#          [0.1950, 0.2098, 0.3445, 0.2507],
#          [0.1151, 0.3902, 0.0346, 0.4601]]])
# Preferences:  tensor([[[0.2500, 1.0000, 0.5000, 0.7500],
#          [0.5000, 0.7500, 1.0000, 0.2500],
#          [0.2500, 1.0000, 0.5000, 0.7500],
#          [0.2500, 0.5000, 0.7500, 1.0000]]])
# Violations: tensor([[0.6299]])
# Time taken for iteration 74: 0.733725 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 75
# P:  tensor([[[0.0627, 0.2637, 0.4643, 0.2093],
#          [0.4687, 0.2529, 0.1168, 0.1616],
#          [0.0444, 0.4805, 0.1832, 0.2920],
#          [0.4242, 0.0030, 0.2357, 0.3371]]])
# Preferences:  tensor([[[0.2500, 1.0000, 0.7500, 0.5000],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [1.0000, 0.7500, 0.5000, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[0.6067]])
# Time taken for iteration 75: 0.722605 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 76
# P:  tensor([[[0.3053, 0.1947, 0.3495, 0.1505],
#          [0.3269, 0.1042, 0.2141, 0.3548],
#          [0.0872, 0.4619, 0.2859, 0.1650],
#          [0.2806, 0.2392, 0.1504, 0.3297]]])
# Preferences:  tensor([[[0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [0.5000, 0.7500, 0.2500, 1.0000]]])
# Violations: tensor([[1.2685]])
# Time taken for iteration 76: 0.744909 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 77
# P:  tensor([[[0.3682, 0.2230, 0.1918, 0.2169],
#          [0.0533, 0.2671, 0.4193, 0.2603],
#          [0.3349, 0.0929, 0.3745, 0.1977],
#          [0.2436, 0.4169, 0.0144, 0.3252]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [0.5000, 0.7500, 0.2500, 1.0000]]])
# Violations: tensor([[1.2245]])
# Time taken for iteration 77: 0.692401 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 78
# P:  tensor([[[0.2345, 0.1461, 0.3204, 0.2989],
#          [0.3619, 0.1549, 0.2596, 0.2236],
#          [0.0602, 0.3191, 0.2902, 0.3305],
#          [0.3433, 0.3799, 0.1298, 0.1471]]])
# Preferences:  tensor([[[0.7500, 0.2500, 0.5000, 1.0000],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500]]])
# Violations: tensor([[1.5080]])
# Time taken for iteration 78: 0.728945 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 79
# P:  tensor([[[0.1777, 0.2396, 0.2738, 0.3089],
#          [0.3089, 0.1746, 0.2597, 0.2567],
#          [0.1636, 0.3588, 0.2785, 0.1991],
#          [0.3498, 0.2270, 0.1879, 0.2353]]])
# Preferences:  tensor([[[0.2500, 0.7500, 1.0000, 0.5000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.7500, 0.2500, 0.5000, 1.0000]]])
# Violations: tensor([[0.5275]])
# Time taken for iteration 79: 0.756221 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 80
# P:  tensor([[[0.2293, 0.1860, 0.1657, 0.4190],
#          [0.2694, 0.2213, 0.3946, 0.1147],
#          [0.1966, 0.3242, 0.4233, 0.0559],
#          [0.3048, 0.2685, 0.0164, 0.4103]]])
# Preferences:  tensor([[[0.7500, 0.2500, 1.0000, 0.5000],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.2500, 1.0000, 0.5000, 0.7500]]])
# Violations: tensor([[0.5905]])
# Time taken for iteration 80: 0.808164 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 81
# P:  tensor([[[0.1194, 0.3390, 0.2485, 0.2930],
#          [0.4366, 0.1567, 0.2983, 0.1083],
#          [0.1935, 0.1221, 0.1252, 0.5593],
#          [0.2504, 0.3822, 0.3280, 0.0393]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [0.7500, 0.5000, 0.2500, 1.0000],
#          [0.7500, 1.0000, 0.2500, 0.5000]]])
# Violations: tensor([[1.2845]])
# Time taken for iteration 81: 0.756179 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 82
# P:  tensor([[[0.3480, 0.3795, 0.1937, 0.0788],
#          [0.2448, 0.1382, 0.1683, 0.4487],
#          [0.3987, 0.1540, 0.3597, 0.0877],
#          [0.0086, 0.3283, 0.2783, 0.3848]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000]]])
# Violations: tensor([[0.8841]])
# Time taken for iteration 82: 0.701795 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 83
# P:  tensor([[[0.3547, 0.3379, 0.2883, 0.0191],
#          [0.2089, 0.2320, 0.3442, 0.2149],
#          [0.1148, 0.3126, 0.2039, 0.3687],
#          [0.3216, 0.1175, 0.1636, 0.3973]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.4554]])
# Time taken for iteration 83: 0.744027 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 84
# P:  tensor([[[0.1999, 0.0106, 0.4320, 0.3574],
#          [0.2811, 0.3907, 0.1141, 0.2142],
#          [0.2986, 0.0980, 0.3266, 0.2767],
#          [0.2204, 0.5007, 0.1273, 0.1517]]])
# Preferences:  tensor([[[0.5000, 0.2500, 1.0000, 0.7500],
#          [0.7500, 0.5000, 0.2500, 1.0000],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.0160]])
# Time taken for iteration 84: 0.723925 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 85
# P:  tensor([[[0.1166, 0.3887, 0.2064, 0.2883],
#          [0.0211, 0.2724, 0.3281, 0.3784],
#          [0.6567, 0.1113, 0.1219, 0.1101],
#          [0.2056, 0.2276, 0.3436, 0.2232]]])
# Preferences:  tensor([[[0.5000, 0.7500, 1.0000, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500],
#          [1.0000, 0.2500, 0.5000, 0.7500]]])
# Violations: tensor([[0.8587]])
# Time taken for iteration 85: 0.700701 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 86
# P:  tensor([[[0.1271, 0.3613, 0.4343, 0.0774],
#          [0.3149, 0.1590, 0.5021, 0.0241],
#          [0.1883, 0.4030, 0.0054, 0.4034],
#          [0.3697, 0.0767, 0.0583, 0.4952]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [0.7500, 1.0000, 0.2500, 0.5000]]])
# Violations: tensor([[1.4349]])
# Time taken for iteration 86: 0.729533 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 87
# P:  tensor([[[0.3564, 0.2736, 0.1642, 0.2057],
#          [0.3755, 0.1832, 0.0806, 0.3607],
#          [0.0077, 0.1925, 0.5758, 0.2240],
#          [0.2604, 0.3507, 0.1793, 0.2096]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.5000, 1.0000, 0.7500, 0.2500],
#          [0.7500, 0.2500, 1.0000, 0.5000],
#          [0.7500, 1.0000, 0.2500, 0.5000]]])
# Violations: tensor([[0.8097]])
# Time taken for iteration 87: 0.704954 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 88
# P:  tensor([[[0.2594, 0.4754, 0.0098, 0.2554],
#          [0.4407, 0.0398, 0.5058, 0.0138],
#          [0.1313, 0.3403, 0.2261, 0.3024],
#          [0.1687, 0.1445, 0.2584, 0.4284]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.2500, 1.0000, 0.7500, 0.5000],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.4484]])
# Time taken for iteration 88: 0.677046 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 89
# P:  tensor([[[0.1888, 0.1882, 0.1090, 0.5141],
#          [0.3850, 0.2531, 0.2011, 0.1608],
#          [0.3443, 0.1709, 0.2511, 0.2337],
#          [0.0819, 0.3878, 0.4388, 0.0915]]])
# Preferences:  tensor([[[1.0000, 0.7500, 0.5000, 0.2500],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [0.7500, 0.2500, 0.5000, 1.0000]]])
# Violations: tensor([[1.1078]])
# Time taken for iteration 89: 0.693583 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 90
# P:  tensor([[[0.4552, 0.0820, 0.2525, 0.2103],
#          [0.2641, 0.2742, 0.2257, 0.2360],
#          [0.0109, 0.4258, 0.2784, 0.2849],
#          [0.2698, 0.2180, 0.2435, 0.2687]]])
# Preferences:  tensor([[[0.2500, 0.7500, 0.5000, 1.0000],
#          [0.5000, 0.2500, 1.0000, 0.7500],
#          [1.0000, 0.2500, 0.5000, 0.7500],
#          [0.5000, 1.0000, 0.2500, 0.7500]]])
# Violations: tensor([[2.0439]])
# Time taken for iteration 90: 0.722914 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 91
# P:  tensor([[[0.1281, 0.3589, 0.2740, 0.2390],
#          [0.0474, 0.3523, 0.2806, 0.3196],
#          [0.4985, 0.1899, 0.1668, 0.1448],
#          [0.3260, 0.0989, 0.2786, 0.2966]]])
# Preferences:  tensor([[[0.7500, 0.2500, 1.0000, 0.5000],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [0.5000, 0.2500, 0.7500, 1.0000],
#          [1.0000, 0.5000, 0.2500, 0.7500]]])
# Violations: tensor([[1.2245]])
# Time taken for iteration 91: 0.682579 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 92
# P:  tensor([[[0.3315, 0.1528, 0.2350, 0.2806],
#          [0.0234, 0.4536, 0.1294, 0.3936],
#          [0.3681, 0.2301, 0.3859, 0.0159],
#          [0.2770, 0.1634, 0.2496, 0.3100]]])
# Preferences:  tensor([[[0.2500, 1.0000, 0.5000, 0.7500],
#          [1.0000, 0.2500, 0.7500, 0.5000],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [1.0000, 0.7500, 0.2500, 0.5000]]])
# Violations: tensor([[0.8472]])
# Time taken for iteration 92: 0.710166 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 93
# P:  tensor([[[0.1191, 0.2799, 0.0507, 0.5503],
#          [0.2162, 0.0392, 0.4915, 0.2531],
#          [0.2932, 0.3691, 0.2627, 0.0749],
#          [0.3715, 0.3118, 0.1951, 0.1216]]])
# Preferences:  tensor([[[1.0000, 0.2500, 0.5000, 0.7500],
#          [1.0000, 0.7500, 0.5000, 0.2500],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.7500, 0.5000, 1.0000, 0.2500]]])
# Violations: tensor([[1.0981]])
# Time taken for iteration 93: 0.671565 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 94
# P:  tensor([[[0.1409, 0.1023, 0.3381, 0.4187],
#          [0.1766, 0.4006, 0.2155, 0.2073],
#          [0.2808, 0.3539, 0.1738, 0.1915],
#          [0.4016, 0.1432, 0.2727, 0.1825]]])
# Preferences:  tensor([[[1.0000, 0.5000, 0.7500, 0.2500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.7500, 1.0000, 0.5000, 0.2500],
#          [0.5000, 0.2500, 1.0000, 0.7500]]])
# Violations: tensor([[1.3675]])
# Time taken for iteration 94: 0.719050 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 95
# P:  tensor([[[0.4629, 0.2552, 0.2161, 0.0659],
#          [0.4201, 0.1294, 0.2841, 0.1663],
#          [0.0915, 0.2828, 0.4028, 0.2230],
#          [0.0256, 0.3326, 0.0970, 0.5447]]])
# Preferences:  tensor([[[0.5000, 0.7500, 0.2500, 1.0000],
#          [0.5000, 0.7500, 0.2500, 1.0000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[1.1601]])
# Time taken for iteration 95: 0.712100 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 96
# P:  tensor([[[0.1040, 0.1907, 0.3864, 0.3188],
#          [0.0248, 0.4325, 0.3056, 0.2371],
#          [0.0661, 0.3480, 0.2397, 0.3462],
#          [0.8050, 0.0288, 0.0683, 0.0979]]])
# Preferences:  tensor([[[0.5000, 0.2500, 0.7500, 1.0000],
#          [0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 0.5000, 0.7500, 1.0000],
#          [0.5000, 1.0000, 0.7500, 0.2500]]])
# Violations: tensor([[1.0083]])
# Time taken for iteration 96: 0.687033 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 97
# P:  tensor([[[0.0399, 0.4974, 0.2155, 0.2472],
#          [0.0416, 0.2313, 0.4896, 0.2375],
#          [0.3812, 0.2077, 0.2492, 0.1619],
#          [0.5374, 0.0635, 0.0457, 0.3534]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.2500, 0.7500],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [0.7500, 1.0000, 0.2500, 0.5000],
#          [0.7500, 1.0000, 0.5000, 0.2500]]])
# Violations: tensor([[0.6960]])
# Time taken for iteration 97: 0.688948 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 98
# P:  tensor([[[0.3823, 0.3670, 0.2191, 0.0316],
#          [0.1056, 0.2932, 0.2397, 0.3615],
#          [0.3343, 0.0666, 0.2394, 0.3597],
#          [0.1778, 0.2733, 0.3018, 0.2472]]])
# Preferences:  tensor([[[0.7500, 0.2500, 1.0000, 0.5000],
#          [0.2500, 0.7500, 1.0000, 0.5000],
#          [0.2500, 0.5000, 1.0000, 0.7500],
#          [1.0000, 0.2500, 0.7500, 0.5000]]])
# Violations: tensor([[1.1031]])
# Time taken for iteration 98: 0.676425 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 99
# P:  tensor([[[0.1144, 0.2147, 0.1476, 0.5233],
#          [0.3417, 0.1237, 0.2274, 0.3073],
#          [0.2650, 0.2710, 0.4294, 0.0347],
#          [0.2790, 0.3906, 0.1956, 0.1348]]])
# Preferences:  tensor([[[0.5000, 1.0000, 0.7500, 0.2500],
#          [0.5000, 0.2500, 0.7500, 1.0000],
#          [1.0000, 0.7500, 0.2500, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000]]])
# Violations: tensor([[1.4167]])
# Time taken for iteration 99: 0.709072 sec
# Cycles: 8
# --------------------------------------------------
# Iteration 100
# P:  tensor([[[0.2216, 0.3992, 0.1264, 0.2528],
#          [0.0582, 0.0975, 0.4789, 0.3655],
#          [0.3059, 0.1943, 0.2773, 0.2226],
#          [0.4143, 0.3090, 0.1175, 0.1592]]])
# Preferences:  tensor([[[0.7500, 1.0000, 0.2500, 0.5000],
#          [0.2500, 0.7500, 0.5000, 1.0000],
#          [0.7500, 0.2500, 0.5000, 1.0000],
#          [1.0000, 0.2500, 0.5000, 0.7500]]])
# Violations: tensor([[0.9153]])
# Time taken for iteration 100: 0.718978 sec
# Cycles: 8
# --------------------------------------------------
